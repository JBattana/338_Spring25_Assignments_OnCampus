# %% [markdown]
# 1. Train a Decision Tree Regressor to predict the Literacy Rate (lit_rate_adult_pct) using all other features as predictors.
#
# Report the training and testing R² scores and explain what the score means.
#
# Visualize the decision tree (use max_depth=4).

# %% [markdown]
# Which features are the most important in predicting literacy rates?
#
# Why do you think these features influence the literacy rate? Provide explanations based on the dataset and context
#
# For example: Higher expenditure improves literacy

# %% [markdown]
# 2. Use Random Forest Regression to predict Literacy Rate (lit_rate_adult_pct).
#
# Extract the feature importance scores from the model.
#
# Specifically discuss the role of Government Expenditure on Education (gov_exp_pct_gdp) in the prediction.
#
#
# Is Government Expenditure one of the top predictors of Literacy Rate?
# If yes, explain why it may strongly influence literacy. If not, suggest why other features might have greater importance
#
# For example: Pupil-teacher ratios or school enrollment

# %% [markdown]
# 3. Analyze the linear correlation between Pupil-Teacher Ratio (pupil_teacher_primary) and Primary Completion Rate (pri_comp_rate_pct) first.
#
# Use a Decision Tree Regressor to check how well the model predicts the Primary Completion Rate based on only Pupil-Teacher Ratio.
#
#
# Does the Decision Tree capture the relationship effectively?
#
# Does a high pupil-teacher ratio appear to negatively impact primary completion?

# %% [markdown]
# 4. Suppose you are analyzing United States educational performance with the following indicators:
#
# Government Expenditure on Education (gov_exp_pct_gdp): 5.8% of GDP
#
# Pupil-Teacher Ratio (pupil_teacher_primary): 30
#
# Primary Enrollment Rate (school_enrol_primary_pct): 80%
#
# Secondary Enrollment Rate (school_enrol_secondary_pct): 70%
#
# Use your Random Forest Regression model to predict:
#
# Primary Completion Rate (pri_comp_rate_pct)
# Literacy Rate (lit_rate_adult_pct)
#
#
# Based on the predictions, analyze the country's educational performance.
# Compare the predicted values with global averages and suggest potential areas of improvement.
