# %% [markdown]
# 1. A company’s HR department wants to estimate the probability of employees completing a training course. The probability of an employee completing the course is 0.8, and there are 10 employees.

# %%
# The code below calculates uses binomial distribution to find the probabilities for different numbers of employees completing the course

from scipy.stats import binom

n = 10
p = 0.8

x = range(0,11,1)
print(x)

probabilities = binom.pmf(x, n, p)

# To unpack the list generated from the range and display index and values, we use ennumerate
for i, prob in enumerate(probabilities):
    print(f"(Probability of {i} employees completing the course): {prob:.3f}")
# Out:
# range(0, 11)
# (Probability of 0 employees completing the course): 0.000
# (Probability of 1 employees completing the course): 0.000
# (Probability of 2 employees completing the course): 0.000
# (Probability of 3 employees completing the course): 0.001
# (Probability of 4 employees completing the course): 0.006
# (Probability of 5 employees completing the course): 0.026
# (Probability of 6 employees completing the course): 0.088
# (Probability of 7 employees completing the course): 0.201
# (Probability of 8 employees completing the course): 0.302
# (Probability of 9 employees completing the course): 0.268
# (Probability of 10 employees completing the course): 0.107

# %% [markdown]
# What does the output tell you about the likelihood of all employees completing the course versus only a few completing it?

# %% [markdown]
# 2. Identify the Probability Distribution for each scenario.
#
# The probability distributions are: Normal, Binomial, Poisson and Conditional Probability.
#
# The number of emails received by a customer support team in an hour.
#
# The heights of trees in a forest.
#
# The probability of getting exactly 3 heads in 10 coin tosses.
#
# The probability that a patient has a disease given that they tested positive.

# %% [markdown]
# 3. The number of customers arriving at a cafe follows a Poisson distribution with an average arrival rate of 5 customers per hour.

# %%
# Finish the code to calculate the probability of exactly 3 customers arriving in a given hour.

from scipy.stats import poisson

rate = 5
k = 3

# Complete this code to calculate the probability
# probability =

# print(f"Probability(3 customers in an hour): {probability:.3f}")

# %% [markdown]
# Also answer: What would happen to the probability if the arrival rate increased to 8 customers per hour? Explain your answer

# %% [markdown]
# 4. You are analyzing a dataset where:
#
# 70% of people own a smartphone.
#
# 50% of people with smartphones use it for online shopping.
#
# 30% of people without smartphones use it for online shopping.
#
# **Answer** **the** **following**:
# You can choose to solve the question mathematically or use a python code and explain your result.
#
# What is the probability that a randomly selected person uses a smartphone for online shopping?
#
# What is the probability that a person uses online shopping, given that they own a smartphone?

# %% [markdown]
# 5. You are working with a dataset that tracks the delivery times of a shipping company. Delivery time is normally distributed with a mean of 2 days and a standard deviation of 0.5 days.
#
# Answer the following: You can choose to solve the question mathematically or use a python code and explain your result.
#
#
# What proportion of deliveries take less than 1.5 days?
#
# What proportion of deliveries take between 2 and 3 days?

# %% [markdown]
# 6. You are analyzing the distribution of weights of packages processed at a shipping center. The recorded sample weights (in kg) are:
#
# 10.5, 12.3, 11.7, 13.0, 10.8, 12.9, 11.5, 10.6, 12.1, 11.9
#
# Write python code to:
#
# Calculate the mean and standard deviation of the given data.
#
# Plot a histogram of the given data.
#
# Write the code to find the probability density function (PDF) of the normal distribution on the histogram using the calculated mean and standard deviation.
