# %% [markdown]
# 1. A food company claims that its new protein bar contains 20 grams of protein per serving. A consumer group suspects the claim might be inaccurate. They randomly sample 30 protein bars and find the following protein contents (in grams):
#
#
# 19.8, 20.1, 19.5, 20.3, 19.9, 19.7, 20.0, 20.2, 19.6, 19.8,
# 20.0, 19.7, 20.1, 19.9, 19.8, 20.4, 19.6, 20.0, 20.1, 19.8,
# 20.3, 19.9, 19.5, 20.0, 19.8, 20.2, 19.6, 20.1, 19.7, 20.0

# %% [markdown]
# State the null hypothesis and the alternative hypothesis
#
# Perform a one-sample t-test using Python to determine if the mean protein content differs significantly from the claimed value of 20 grams.
# Use a significance level of 0.05
#
# Write your conclusions based on the test result.

# %% [markdown]
# 2. A university claims the average GPA of its students is 3.2. You collect data from 50 randomly selected students and find an average GPA of 3.05 with a standard deviation of 0.4.
#
#
# Perform a z-test to determine if the average GPA differs from the claimed value. Assume a population variance of 𝜎2 = 0.16
#
# Perform a t-test assuming the population variance is unknown.
#
# Compare and interpret the results of the t-test and z-test.

# %% [markdown]
# 3. You are analyzing the salaries of data analysts in a company. A random sample of 40 salaries (in $1000s) has:
#
# Mean salary: 55000
# Standard deviation: 8000
#
# Write Python code to calculate the 95% confidence interval for the population mean salary.
#
# Interpret the confidence interval and explain what it tells you about the mean salary.

# %% [markdown]
# 4. You are analyzing the effectiveness of a new teaching method between two groups Group A and Group B. These groups were taught using different methods, and their test scores were recorded:
#
# Group A: 78, 85, 82, 90, 88, 76, 81, 84, 80, 89
# Group B: 72, 79, 78, 74, 77, 75, 73, 76, 78, 80
#
# Perform an independent two-sample t-test to determine if there is a significant difference in the mean scores of the two groups.
# Assume equal variances and use α=0.05.
#
# Write your conclusions based on the p-value.

# %% [markdown]
# 5. Which of the following statements about hypothesis testing is true?
#
# a) The null hypothesis is a statement of no effect or no difference.
#
# b) A p-value greater than the significance level 𝛼 leads to rejecting the null hypothesis.
#
# c) A one-tailed test checks for deviations in both directions from the null hypothesis.
#
# d) A z-test is always used when the sample size is small.

# %% [markdown]
# 6. Which of the following best describes a 95% confidence interval?
#
# a) There is a 95% probability that the population mean falls within the interval.
#
# b) 95% of the data points in the population fall within the interval.
#
# c) If we repeated the sampling process many times, 95% of the intervals calculated would contain the population mean.
#
# d) The sample mean is guaranteed to be within the 95% confidence interval.
