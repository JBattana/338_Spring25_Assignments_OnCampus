# %% [markdown]
# 1. The bank wants to predict whether a customer will subscribe to a term deposit (y) based on their profile.
#
# Use a KNN classifier with features such as age, balance, housing, and loan.
#
# Normalize the numeric features age, balance
#
# Find the optimal value of K and evaluate the model performance using a confusion matrix and ROC curve.
#
# Explain how the choice of k affects the predictions.

# %% [markdown]
# 2. The bank wants to identify customers likely to subscribe to a term deposit (y).
#
# Train a logistic regression model using features like age, balance, job, education, and housing to predict the likelihood of subscription.
#
#
# Perform one-hot encoding for categorical variables job and education.
#
# Split the data into training and testing sets and evaluate the model.
#
# Explain which features had the most significant impact on the subscription and why logistic regression is suitable for this task.

# %% [markdown]
# 3. The bank wants to understand which factors influence a customer's decision to subscribe to a term deposit.
#
# Use a decision tree classifier to identify the most important features for predicting y.
#
# Train the decision tree model and extract feature importance values.
#
# Visualize the feature importances using a bar plot.
#
# Explain why the most important features might influence a customer’s decision.

# %% [markdown]
# 4. Compare the logistic regression, KNN, and decision trees models using the same features to predict y.
#
# Explain which model performed best and why, considering the nature of the dataset.
